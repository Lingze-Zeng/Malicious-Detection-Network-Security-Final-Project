# %%
import requests
import pandas as pd
import numpy as np
from IPython.display import clear_output

r = requests.get(url='https://corporationwiki.com/Ohio/Columbus/frank-s-benson-P3333917.aspx')
print(r)
print(type(r))
# Out:
# <Response [403]>
# <class 'requests.models.Response'>

# %%
df = pd.read_csv('malicious_phish.csv')
MURL_NPlist = df.to_numpy()
# print(MURL_NPlist[:,1])
new_dim = np.zeros((MURL_NPlist.shape[0],3))
# print(new_dim)
# print(new_dim.shape[0])
pre_shaped_MURL_NPlist = np.append(MURL_NPlist,new_dim,axis=1)
i = 0
active_url = 0
bengin_url = 0
defacement_url = 0
phishing_url = 0
while phishing_url < 300:
    try:
        try:
            j=0
            while j<3:
                try:
                    r = requests.get(url=pre_shaped_MURL_NPlist[i,0],timeout=5)
                    break
                except requests.exceptions.Timeout:
                    j+=1
        except requests.exceptions.MissingSchema:
            j=0
            while j<3:
                try:
                    r = requests.get(url = 'http://' + pre_shaped_MURL_NPlist[i,0],timeout=5)
                    break
                except requests.exceptions.Timeout:
                    j+=1
        pre_shaped_MURL_NPlist[i,2] = r.status_code
        # print(r.status_code)
    except requests.RequestException as e:
        i+=1
        # print(e)
        continue
    if r.status_code == 200:
        pre_shaped_MURL_NPlist[i,3] = 1
        active_url+=1
        pre_shaped_MURL_NPlist[i,4] = r.text
        if pre_shaped_MURL_NPlist[i,1] == 'benign':
            bengin_url+=1
        elif pre_shaped_MURL_NPlist[i,1] == 'defacement':
            defacement_url+=1
        elif pre_shaped_MURL_NPlist[i,1] == 'phishing':
            phishing_url+=1
    i+=1
    print('\r', i, '\nactive:     ', active_url, '\nbenign:     ', bengin_url,'\ndefacement: ', defacement_url, '\nphishing:   ', phishing_url)
    clear_output(wait=True)
print(pre_shaped_MURL_NPlist[0:i-1,:])
print('active:     ', active_url)
print('benign:     ', bengin_url)
print('defacement: ', defacement_url)
print('phishing:   ', phishing_url)
# Out:
# [['br-icloud.com.br' 'phishing' 0.0 0.0 0.0]
#  ['mp3raid.com/music/krizz_kaliko.html' 'benign' 404 0.0 0.0]
#  ['bopsecrets.org/rexroth/cr/1.htm' 'benign' 200 1
# ...

# %%
print(pre_shaped_MURL_NPlist[10,:])
# Out:
# 9
# ['corporationwiki.com/Ohio/Columbus/frank-s-benson-P3333917.aspx' 'benign'
#  0.0]

# %%
print(r.status_code)
print(r.text)
print(r.url)
# Out:
# 200
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>YUE ZHU</title>
#
#     <!-- font awesom        e cdn link  -->
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/5.15.3/css/all.min.css">
#     <link href='https://cdn.jsdelivr.net/npm/boxicons@2.0.5/css/boxicons.min.css' rel='stylesheet'>
#     <!-- custom css file link  -->
#     <link rel="stylesheet" href="css/style.css">
#
# </head>
# <body>
#
# <!-- custom cursors  -->
# <!-- div class="cursor-1"></！div>
# <div-- class="cursor-2"></div-->
#
#
# <div id="menu-bars" class="fas fa-bars"></div>
#
# <!-- header section starts  -->
#
# <header>
#     <div>
#         <a href="documents/Yue Zhu_Resume.pdf" class="logo" target="_blank"> <span>YUE</span> ZHU </a>
# ...

# %%
print(r.headers)
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '2934', 'Server': 'GitHub.com', 'Content-Type': 'text/html; charset=utf-8', 'permissions-policy': 'interest-cohort=()', 'Last-Modified': 'Thu, 06 Apr 2023 19:47:15 GMT', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31556952', 'ETag': 'W/"642f21c3-2adb"', 'expires': 'Sun, 16 Apr 2023 10:33:03 GMT', 'Cache-Control': 'max-age=600', 'Content-Encoding': 'gzip', 'x-proxy-cache': 'MISS', 'X-GitHub-Request-Id': '2718:275E:625725:8FE69A:643BCC87', 'Accept-Ranges': 'bytes', 'Date': 'Sun, 16 Apr 2023 10:24:32 GMT', 'Via': '1.1 varnish', 'Age': '0', 'X-Served-By': 'cache-iad-kiad7000044-IAD', 'X-Cache': 'HIT', 'X-Cache-Hits': '1', 'X-Timer': 'S1681640672.418192,VS0,VE8', 'Vary': 'Accept-Encoding', 'X-Fastly-Request-ID': 'c1b5e476f4d31a89d8521763b9603876cc427c9d'}
